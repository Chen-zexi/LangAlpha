# %% [markdown]
# # Get Data
# We will using helper fuction under /src to get the data we need

# %% [markdown]
# ## Import liberary

# %%
import sys
import os
import pandas as pd
import warnings
sys.path.append(os.path.abspath('..'))
warnings.filterwarnings("ignore", category=FutureWarning)

from src.yahoo_finance import yahoo_finance
from src.ploygon import polygon

# %% [markdown]
# ## Yahoo Fiance

# %%
tickers = ['AAPL', 'MSFT', 'GOOG', 'AMZN', 'TSLA', 'META', 'NFLX', 'NVDA', 'AMD', 'NVDA', 
           'TSLA', 'BA', 'V', 'GOOG', 'SPY', 'SPCE', 'FB', 'TWTR', 'BABA', 'MSTR', 'DIS', 
           'PYPL', 'SHOP', 'COIN', 'SQ', 'INTC', 'CSCO', 'IBM', 'GE', 'AMD', 'WMT', 'T']

# %%
yf = yahoo_finance()
data = yf.get_data(tickers, '2024-03-18', '2025-03-18')

# %%
df = pd.DataFrame(data)
df
# Out:
#                          open        high         low       close     volume  \
# symbol date
# AAPL   2024-03-18  175.570007  177.710007  173.520004  173.720001   75604200
#        2024-03-19  174.339996  176.610001  173.029999  176.080002   55215200
#        2024-03-20  175.720001  178.669998  175.089996  178.669998   53423100
#        2024-03-21  177.050003  177.490005  170.839996  171.369995  106181300
#        2024-03-22  171.759995  173.050003  170.059998  172.279999   71106600
# ...                       ...         ...         ...         ...        ...
# T      2025-03-11   26.469999   26.830000   25.590000   26.010000   74574300
#        2025-03-12   25.629999   25.860001   24.889999   25.719999   62383200
#        2025-03-13   25.790001   26.459999   25.760000   26.090000   37698500
#        2025-03-14   25.799999   26.650000   25.750000   26.580000   37591300
#        2025-03-17   26.570000   26.930000   26.250000   26.830000   45570000
#
#                      adjclose  dividends  splits
# symbol date
# AAPL   2024-03-18  172.903580        0.0     0.0
#        2024-03-19  175.252487        0.0     0.0
#        2024-03-20  177.830307        0.0     0.0
#        2024-03-21  170.564606        0.0     0.0
#        2024-03-22  171.470352        0.0     0.0
# ...                       ...        ...     ...
# T      2025-03-11   26.010000        0.0     0.0
#        2025-03-12   25.719999        0.0     0.0
#        2025-03-13   26.090000        0.0     0.0
#        2025-03-14   26.580000        0.0     0.0
#        2025-03-17   26.830000        0.0     0.0
#
# [6500 rows x 8 columns]

# %% [markdown]
# ## Polygon

# %%
pl = polygon()
data = pl.get_data('AAPL', multiplier=1, timespan='minute', from_date='2025-03-13', to_date='2025-03-17', limit=100000)
data
# Out:
#      ticker      open    high       low   close  volume      vwap  \
# 0      AAPL  216.0000  216.00  215.7000  215.70  3945.0  215.8287
# 1      AAPL  215.6000  215.60  215.2500  215.40  3347.0  215.3760
# 2      AAPL  215.6000  215.60  215.4000  215.40  1934.0  215.4996
