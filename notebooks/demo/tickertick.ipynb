# %%
import sys
import os
import warnings
# Add the src folder to the path
sys.path.append(os.path.abspath('../..'))
warnings.filterwarnings("ignore", category=FutureWarning)
from src.data_tool.data_providers import tickertick

tt = tickertick.Tickertick()

# %%
news = tt.get_curated_news()

# %%
news
# Out:
# {'stories': [{'id': '-152570462872941362',
#    'title': 'Xavier Le Pichon, Who Modeled Movement of Earth’s Crust, Dies at 87',
#    'url': 'https://www.nytimes.com/2025/04/09/science/xavier-le-pichon-dead.html',
#    'site': 'nytimes.com',
#    'time': '2025-04-09T18:45:09',
#    'favicon_url': 'https://static.tickertick.com/website_icons/nytimes.com.ico',
#    'description': 'With a computer rendering, he helped scientists understand that the earth, with its shifting tectonic plates, is “an extraordinary living being” that is “continuously changing.”'},
#   {'id': '8290175223842396683',
#    'title': 'Skift Global Forum Returns to New York City for Its 12th Edition This September',
#    'url': 'https://skift.com/2025/04/09/skift-global-forum-returns-to-new-york-city-for-its-12th-edition-this-september/',
#    'site': 'skift.com',
#    'time': '2025-04-09T18:43:06',
#    'favicon_url': 'https://static.tickertick.com/website_icons/skift.com.ico',
# ...

# %%
tariff = tt.get_entity_news('recession')
tariff
# Out:
# {'stories': []}

# %%
nvda_sec = tt.get_company_sec_filings('nvda')
nvda_sec
# Out:
# {'stories': [{'id': '149528406419666903',
#    'title': 'NVIDIA CORP: Form 4 - Statement of changes in beneficial ownership of securities',
#    'url': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581025000074/0001045810-25-000074-index.htm',
#    'site': 'sec.gov',
#    'time': '2025-03-25T21:21:46',
#    'favicon_url': 'https://static.tickertick.com/website_icons/sec.gov.ico',
#    'tags': ['nvda'],
#    'tickers': ['nvda']},
#   {'id': '72322276753097771',
#    'title': 'NVIDIA CORP: Form 4 - Statement of changes in beneficial ownership of securities',
#    'url': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581025000072/0001045810-25-000072-index.htm',
#    'site': 'sec.gov',
#    'time': '2025-03-22T00:47:44',
#    'favicon_url': 'https://static.tickertick.com/website_icons/sec.gov.ico',
#    'tags': ['nvda'],
#    'tickers': ['nvda']},
#   {'id': '8120560935205564710',
# ...

# %%
xpev_news = tt.get_ticker_news('xpev')
xpev_news
# Out:
# {'stories': [{'id': '3070469943621526756',
#    'title': 'Why Tesla Is A High-Stakes Gamble Now | $BYDDF $BYDDY $ZK $XPEV $XPNGF',
#    'url': 'https://seekingalpha.com/article/4774028-why-tesla-is-a-high-stakes-gamble-now',
#    'site': 'seekingalpha.com',
#    'time': '2025-04-09T16:31:08',
#    'favicon_url': 'https://static.tickertick.com/website_icons/seekingalpha.com.ico',
#    'tags': ['xpev'],
#    'tickers': ['xpev']},
#   {'id': '-2683935005912730420',
#    'title': 'China Electric Vehicle Market Report 2025: Leading Domestic Players BYD, NIO, XPeng and Geely are at the Forefront of the Industry, Pioneering New Battery Technologies and Global Expansion Strategies',
#    'url': 'https://www.globenewswire.com/en/news-release/2025/04/09/3058233/28124/en/China-Electric-Vehicle-Market-Report-2025-Leading-Domestic-Players-BYD-NIO-XPeng-and-Geely-are-at-the-Forefront-of-the-Industry-Pioneering-New-Battery-Technologies-and-Global-Expan.html',
#    'site': 'globenewswire.com',
# ...
